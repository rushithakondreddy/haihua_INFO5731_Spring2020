# %% [markdown]
# <a href="https://colab.research.google.com/github/rushithakondreddy/haihua_INFO5731_Spring2020/blob/main/Copy_of_INFO5731_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
import nltk
import pandas as pd
df = pd.read_csv('review_data.csv')
df['word_count'] = df['review_content'].apply(lambda x:len(str(x).split(" ")))
df
# Out:
#     Unnamed: 0                                     review_content  word_count
# 0            0  I was a person that saw all the hype and claim...         191
# 1            1  Every once in a while a movie comes, that trul...          83
# 2            2  This is a movie that only those who have felt ...          81
# 3            3  Truly a masterpiece, The Best Hollywood film o...         133
# 4            4  Most of the time movies are anticipated like t...          94
# ..         ...                                                ...         ...
# 95          95  Dark, depressing and unsettling film with a ha...          28
# 96          96  I just didn't get the hype about this movie. A...          73
# 97          97  Story was just really unconvincing. Nobody rea...          54
# 98          98  JOKER is a gift to the audiences. I felt as a ...          49
# 99          99  There is doing an homage and then there is bor...          92
#
# [100 rows x 3 columns]

# %%
df['review_content'] = df['review_content'].str.replace('[^\w\s]','')  #removal of punctuation
df['review_content'] = df['review_content'].apply(lambda x: " ".join(x.lower() for x in x.split()))#lower case
from nltk.corpus import stopwords #removal of stopwords
nltk.download('stopwords')
stop = stopwords.words('english')
df['review_content'] = df['review_content'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#converting to a single line file
line = ''
for i in range(0,len(df['review_content'])):
  line+= df['review_content'][i]
print(line)
# Out:
# person saw hype claims masterpiece overreacting overblown excitement another joker based film thought looked solid best even bit pretentious trailer say incredibly wrong massive achievement cinema thats extremely rare day age cgi nonsense reboots somewhat reboot sorts standalone origin tale impeccable start finish echoes resemblance best joker origin comics past joaquin bleeds sweats cries every drop magnificently dedicated performance heath ledger would proud undoubtedly greatest acting performance since heaths joker directing writing slickly brilliant bleak settings tones palpable throughout film place blown away every audience member awestruck witnessed film could still transport characters world existence believe hype going revered transcending masterpiece cinemaevery movie comes truly makes impact joaquins performance scenography brilliance grotesque haunting cringy hard watch times mesmerizing wont blink eye watching tragic seriously funny moments emotional rollercoaster sometimes multiple emotions poppingup timethis far typical actionriddled predictable superhero movie proper psychological thrillerdrama single best character development ever seenmovie felt alone isolated truly relate understand motive feel sorry character lot people see movie think encourages violence truly movie encourage every one us become better person treat everyone respect make feel like belong world instead making feel isolatedtruly masterpiece best hollywood film 2019 one best films decade truly best film bring comic book chillingly realistically real ife remarkable direction cinematography music acting people surprised find disturbing violent necessity message society reflects underappreciatedunrecognizedbullied people proving something way shows class difference corruption rich talented rule others around exaggerated thats makes different believable could multiple jokers living society could shake around much bitter way film shows making people uncomforting people consider wake call message first film perfect filmtime movies anticipated like end falling short way short joker first time happy hype please ignore complaints pernicious violence embarrassing say least havent seen comic movie real ever deserved better class criminal phillips phoenix delivered dark joker dark fall love villain bad guys always romantic anywayjoaquin phoenix gives tour de force performance fearless stunning emotional depth physicality impossible talk without referencing heath ledgers oscarwinning performance dark knight widely considered definitive liveaction portrayal joker lets talk fact everyone going stunned phoenix accomplishes many thought impossible portrayal matches potentially exceeds dark knights clown prince crimelet start saying joaquin phoneix doesnt get oscar movie oscars cancelled phoneix amazing mightve heard every review ever todd phillips best story lines takes visuals breathtaking score omg score every time score came felt uncomfortable like something horrible happen great inspirations taxi driver king comedy add much movie got honest scenes violent disturbing honestly expected wayyyy violent controversy going overall movie great come oscar season needs nominated best picture screenplay cinematography actor score directorget people hate political message people think need get empathy arthurs madness come point never enjoy masterpiece joaquin phoenix todd phillips overdid movie actingmusic cinematography amazing please enjoy movie without overthinkingseen joker yesterday venice early illfated screening trouble audio lead nearhour delay definitely worth itjoker deserved presented venice film festival event regards cinema form art film far blockbuster mere entertainer movie films genre areit focuses psyche main character slowly crumbles pressure society thus joaquin phoenix wonderful performance earning almost surely nomination oscars least take joker differs ledgers id say equally good main difference might ledgers joker rational acts insane phoenixs i ...

# %%
#trigrams
nltk.download('punkt')
words = nltk.word_tokenize(line)
result_trigrams = nltk.trigrams(words)
freq_trigrams = nltk.FreqDist(result_trigrams)
freq_trigrams
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# FreqDist({('person', 'saw', 'hype'): 1,
#           ('saw', 'hype', 'claims'): 1,
#           ('hype', 'claims', 'masterpiece'): 1,
#           ('claims', 'masterpiece', 'overreacting'): 1,
#           ('masterpiece', 'overreacting', 'overblown'): 1,
#           ('overreacting', 'overblown', 'excitement'): 1,
#           ('overblown', 'excitement', 'another'): 1,
#           ('excitement', 'another', 'joker'): 1,
#           ('another', 'joker', 'based'): 1,
#           ('joker', 'based', 'film'): 1,
#           ('based', 'film', 'thought'): 1,
#           ('film', 'thought', 'looked'): 1,
#           ('thought', 'looked', 'solid'): 1,
#           ('looked', 'solid', 'best'): 1,
#           ('solid', 'best', 'even'): 1,
#           ('best', 'even', 'bit'): 1,
#           ('even', 'bit', 'pretentious'): 1,
#           ('bit', 'pretentious', 'trailer'): 1,
#           ('pretentious', 'trailer', 'say'): 1,
#           ('trailer', 'say', 'incredibly'): 1,
#           ('say', 'incredibly', 'wrong'): 1,
#           ('incredibly', 'wrong', 'massive'): 1,
#           ('wrong', 'massive', 'achievement'): 1,
#           ('massive', 'achievement', 'cinema'): 1,
#           ('achievement', 'cinema', 'thats'): 1,
#           ('cinema', 'thats', 'extremely'): 1,
#           ('thats', 'extremely', 'rare'): 1,
#           ('extremely', 'rare', 'day'): 1,
#           ('rare', 'day', 'age'): 1,
#           ('day', 'age', 'cgi'): 1,
#           ('age', 'cgi', 'nonsense'): 1,
#           ('cgi', 'nonsense', 'reboots'): 1,
#           ('nonsense', 'reboots', 'somewhat'): 1,
#           ('reboots', 'somewhat', 'reboot'): 1,
#           ('somewhat', 'reboot', 'sorts'): 1,
#           ('reboot', 'sorts', 'standalone'): 1,
#           ('sorts', 'standalone', 'origin'): 1,
#           ('standalone', 'origin', 'tale'): 1,
#           ('origin', 'tale', 'impeccable'): 1,
#           ('tale', 'impeccable', 'start'): 1,
#           ('impeccable', 'start', 'finish'): 1,
#           ('start', 'finish', 'echoes'): 1,
#           ('finish', 'echoes', 'resemblance'): 1,
#           ('echoes', 'resemblance', 'best'): 1,
#           ('resemblance', 'best', 'joker'): 1,
#           ('best', 'joker', 'origin'): 1,
#           ('joker', 'origin', 'comics'): 1,
#           ('origin', 'comics', 'past'): 1,
#           ('comics', 'past', 'joaquin'): 1,
#           ('past', 'joaquin', 'bleeds'): 1,
#           ('joaquin', 'bleeds', 'sweats'): 1,
#           ('bleeds', 'sweats', 'cries'): 1,
#           ('sweats', 'cries', 'every'): 1,
#           ('cries', 'every', 'drop'): 1,
#           ('every', 'drop', 'magnificently'): 1,
#           ('drop', 'magnificently', 'dedicated'): 1,
#           ('magnificently', 'dedicated', 'performance'): 1,
#           ('dedicated', 'performance', 'heath'): 1,
#           ('performance', 'heath', 'ledger'): 1,
#           ('heath', 'ledger', 'would'): 1,
#           ('ledger', 'would', 'proud'): 1,
#           ('would', 'proud', 'undoubtedly'): 1,
#           ('proud', 'undoubtedly', 'greatest'): 1,
#           ('undoubtedly', 'greatest', 'acting'): 1,
#           ('greatest', 'acting', 'performance'): 1,
#           ('acting', 'performance', 'since'): 1,
#           ('performance', 'since', 'heaths'): 1,
#           ('since', 'heaths', 'joker'): 1,
#           ('heaths', 'joker', 'directing'): 1,
#           ('joker', 'directing', 'writing'): 1,
#           ('directing', 'writing', 'slickly'): 1,
#           ('writing', 'slickly', 'brilliant'): 1,
#           ('slickly', 'brilliant', 'bleak'): 1,
#           ('brilliant', 'bleak', 'settings'): 1,
#           ('bleak', 'settings', 'tones'): 1,
#           ('settings', 'tones', 'palpable'): 1,
#           ('tones', 'palpable', 'throughout'): 1,
#           ('palpable', 'throughout', 'film'): 1,
#           ('throughout', 'film', 'place'): 1,
#           ('film', 'place', 'blown'): 1,
#           ('place', 'blown', 'away'): 1,
#           ('blown', 'away', 'every'): 1,
#           ('away', 'every', 'audience'): 1,
#           ('every', 'audience', 'member'): 1,
#           ('audience', 'member', 'awestruck'): 1,
#           ('member', 'awestruck', 'witnessed'): 1,
#           ('awestruck', 'witnessed', 'film'): 1,
#           ('witnessed', 'film', 'could'): 1,
#           ('film', 'could', 'still'): 1,
#           ('could', 'still', 'transport'): 1,
#           ('still', 'transport', 'characters'): 1,
#           ('transport', 'characters', 'world'): 1,
#           ('characters', 'world', 'existence'): 1,
#           ('world', 'existence', 'believe'): 1,
#           ('existence', 'believe', 'hype'): 1,
#           ('believe', 'hype', 'going'): 1,
#           ('hype', 'going', 'revered'): 1,
#           ('going', 'revered', 'transcending'): 1,
#           ('revered', 'transcending', 'masterpiece'): 1,
#           ('transcending', 'masterpiece', 'cinemaevery'): 1,
#           ('masterpiece', 'cinemaevery', 'movie'): 1,
#           ('cinemaevery', 'movie', 'comes'): 1,
#           ('movie', 'comes', 'truly'): 1,
#           ('comes', 'truly', 'makes'): 1,
#           ('truly', 'makes', 'impact'): 1,
#           ('makes', 'impact', 'joaquins'): 1,
#           ('impact', 'joaquins', 'performance'): 1,
#           ('joaquins', 'performance', 'scenography'): 1,
#           ('performance', 'scenography', 'brilliance'): 1,
#           ('scenography', 'brilliance', 'grotesque'): 1,
#           ('brilliance', 'grotesque', 'haunting'): 1,
#           ('grotesque', 'haunting', 'cringy'): 1,
#           ('haunting', 'cringy', 'hard'): 1,
#           ('cringy', 'hard', 'watch'): 1,
#           ('hard', 'watch', 'times'): 1,
#           ('watch', 'times', 'mesmerizing'): 1,
#           ('times', 'mesmerizing', 'wont'): 1,
#           ('mesmerizing', 'wont', 'blink'): 1,
#           ('wont', 'blink', 'eye'): 1,
#           ('blink', 'eye', 'watching'): 1,
#           ('eye', 'watching', 'tragic'): 1,
#           ('watching', 'tragic', 'seriously'): 1,
#           ('tragic', 'seriously', 'funny'): 1,
#           ('seriously', 'funny', 'moments'): 1,
#           ('funny', 'moments', 'emotional'): 1,
#           ('moments', 'emotional', 'rollercoaster'): 1,
#           ('emotional', 'rollercoaster', 'sometimes'): 1,
#           ('rollercoaster', 'sometimes', 'multiple'): 1,
#           ('sometimes', 'multiple', 'emotions'): 1,
#           ('multiple', 'emotions', 'poppingup'): 1,
#           ('emotions', 'poppingup', 'timethis'): 1,
#           ('poppingup', 'timethis', 'far'): 1,
#           ('timethis', 'far', 'typical'): 1,
#           ('far', 'typical', 'actionriddled'): 1,
#           ('typical', 'actionriddled', 'predictable'): 1,
#           ('actionriddled', 'predictable', 'superhero'): 1,
#           ('predictable', 'superhero', 'movie'): 1,
#           ('superhero', 'movie', 'proper'): 1,
#           ('movie', 'proper', 'psychological'): 1,
#           ('proper', 'psychological', 'thrillerdrama'): 1,
#           ('psychological', 'thrillerdrama', 'single'): 1,
#           ('thrillerdrama', 'single', 'best'): 1,
#           ('single', 'best', 'character'): 1,
#           ('best', 'character', 'development'): 1,
#           ('character', 'development', 'ever'): 1,
#           ('development', 'ever', 'seenmovie'): 1,
#           ('ever', 'seenmovie', 'felt'): 1,
#           ('seenmovie', 'felt', 'alone'): 1,
#           ('felt', 'alone', 'isolated'): 1,
#           ('alone', 'isolated', 'truly'): 1,
#           ('isolated', 'truly', 'relate'): 1,
#           ('truly', 'relate', 'understand'): 1,
#           ('relate', 'understand', 'motive'): 1,
#           ('understand', 'motive', 'feel'): 1,
#           ('motive', 'feel', 'sorry'): 1,
#           ('feel', 'sorry', 'character'): 1,
#           ('sorry', 'character', 'lot'): 1,
#           ('character', 'lot', 'people'): 1,
#           ('lot', 'people', 'see'): 1,
#           ('people', 'see', 'movie'): 1,
#           ('see', 'movie', 'think'): 1,
#           ('movie', 'think', 'encourages'): 1,
#           ('think', 'encourages', 'violence'): 1,
#           ('encourages', 'violence', 'truly'): 1,
#           ('violence', 'truly', 'movie'): 1,
#           ('truly', 'movie', 'encourage'): 1,
#           ('movie', 'encourage', 'every'): 1,
#           ('encourage', 'every', 'one'): 1,
#           ('every', 'one', 'us'): 1,
#           ('one', 'us', 'become'): 1,
#           ('us', 'become', 'better'): 1,
#           ('become', 'better', 'person'): 1,
#           ('better', 'person', 'treat'): 1,
#           ('person', 'treat', 'everyone'): 1,
#           ('treat', 'everyone', 'respect'): 1,
#           ('everyone', 'respect', 'make'): 1,
#           ('respect', 'make', 'feel'): 1,
#           ('make', 'feel', 'like'): 1,
#           ('feel', 'like', 'belong'): 1,
#           ('like', 'belong', 'world'): 1,
#           ('belong', 'world', 'instead'): 1,
#           ('world', 'instead', 'making'): 1,
#           ('instead', 'making', 'feel'): 1,
#           ('making', 'feel', 'isolatedtruly'): 1,
#           ('feel', 'isolatedtruly', 'masterpiece'): 1,
#           ('isolatedtruly', 'masterpiece', 'best'): 1,
#           ('masterpiece', 'best', 'hollywood'): 1,
#           ('best', 'hollywood', 'film'): 1,
#           ('hollywood', 'film', '2019'): 1,
#           ('film', '2019', 'one'): 1,
#           ('2019', 'one', 'best'): 1,
#           ('one', 'best', 'films'): 1,
#           ('best', 'films', 'decade'): 1,
#           ('films', 'decade', 'truly'): 1,
#           ('decade', 'truly', 'best'): 1,
#           ('truly', 'best', 'film'): 1,
#           ('best', 'film', 'bring'): 1,
#           ('film', 'bring', 'comic'): 1,
#           ('bring', 'comic', 'book'): 1,
#           ('comic', 'book', 'chillingly'): 1,
#           ('book', 'chillingly', 'realistically'): 1,
#           ('chillingly', 'realistically', 'real'): 1,
#           ('realistically', 'real', 'ife'): 1,
#           ('real', 'ife', 'remarkable'): 1,
#           ('ife', 'remarkable', 'direction'): 1,
#           ('remarkable', 'direction', 'cinematography'): 1,
#           ('direction', 'cinematography', 'music'): 1,
#           ('cinematography', 'music', 'acting'): 1,
#           ('music', 'acting', 'people'): 1,
#           ('acting', 'people', 'surprised'): 1,
#           ('people', 'surprised', 'find'): 1,
#           ('surprised', 'find', 'disturbing'): 1,
#           ('find', 'disturbing', 'violent'): 1,
#           ('disturbing', 'violent', 'necessity'): 1,
#           ('violent', 'necessity', 'message'): 1,
#           ('necessity', 'message', 'society'): 1,
#           ('message', 'society', 'reflects'): 1,
#           ('society', 'reflects', 'underappreciatedunrecognizedbullied'): 1,
#           ('reflects', 'underappreciatedunrecognizedbullied', 'people'): 1,
#           ('underappreciatedunrecognizedbullied', 'people', 'proving'): 1,
#           ('people', 'proving', 'something'): 1,
#           ('proving', 'something', 'way'): 1,
#           ('something', 'way', 'shows'): 1,
#           ('way', 'shows', 'class'): 1,
#           ('shows', 'class', 'difference'): 1,
#           ('class', 'difference', 'corruption'): 1,
#           ('difference', 'corruption', 'rich'): 1,
#           ('corruption', 'rich', 'talented'): 1,
#           ('rich', 'talented', 'rule'): 1,
#           ('talented', 'rule', 'others'): 1,
#           ('rule', 'others', 'around'): 1,
#           ('others', 'around', 'exaggerated'): 1,
#           ('around', 'exaggerated', 'thats'): 1,
#           ('exaggerated', 'thats', 'makes'): 1,
#           ('thats', 'makes', 'different'): 1,
#           ('makes', 'different', 'believable'): 1,
#           ('different', 'believable', 'could'): 1,
#           ('believable', 'could', 'multiple'): 1,
#           ('could', 'multiple', 'jokers'): 1,
#           ('multiple', 'jokers', 'living'): 1,
#           ('jokers', 'living', 'society'): 1,
#           ('living', 'society', 'could'): 1,
#           ('society', 'could', 'shake'): 1,
#           ('could', 'shake', 'around'): 1,
#           ('shake', 'around', 'much'): 1,
#           ('around', 'much', 'bitter'): 1,
#           ('much', 'bitter', 'way'): 1,
#           ('bitter', 'way', 'film'): 1,
#           ('way', 'film', 'shows'): 1,
#           ('film', 'shows', 'making'): 1,
#           ('shows', 'making', 'people'): 1,
#           ('making', 'people', 'uncomforting'): 1,
#           ('people', 'uncomforting', 'people'): 1,
#           ('uncomforting', 'people', 'consider'): 1,
#           ('people', 'consider', 'wake'): 1,
#           ('consider', 'wake', 'call'): 1,
#           ('wake', 'call', 'message'): 1,
#           ('call', 'message', 'first'): 1,
#           ('message', 'first', 'film'): 1,
#           ('first', 'film', 'perfect'): 1,
#           ('film', 'perfect', 'filmtime'): 1,
#           ('perfect', 'filmtime', 'movies'): 1,
#           ('filmtime', 'movies', 'anticipated'): 1,
#           ('movies', 'anticipated', 'like'): 1,
#           ('anticipated', 'like', 'end'): 1,
#           ('like', 'end', 'falling'): 1,
#           ('end', 'falling', 'short'): 1,
#           ('falling', 'short', 'way'): 1,
#           ('short', 'way', 'short'): 1,
#           ('way', 'short', 'joker'): 1,
#           ('short', 'joker', 'first'): 1,
#           ('joker', 'first', 'time'): 2,
#           ('first', 'time', 'happy'): 1,
#           ('time', 'happy', 'hype'): 1,
#           ('happy', 'hype', 'please'): 1,
#           ('hype', 'please', 'ignore'): 1,
#           ('please', 'ignore', 'complaints'): 1,
#           ('ignore', 'complaints', 'pernicious'): 1,
#           ('complaints', 'pernicious', 'violence'): 1,
#           ('pernicious', 'violence', 'embarrassing'): 1,
#           ('violence', 'embarrassing', 'say'): 1,
#           ('embarrassing', 'say', 'least'): 1,
#           ('say', 'least', 'havent'): 1,
#           ('least', 'havent', 'seen'): 1,
#           ('havent', 'seen', 'comic'): 1,
#           ('seen', 'comic', 'movie'): 1,
#           ('comic', 'movie', 'real'): 1,
#           ('movie', 'real', 'ever'): 1,
#           ('real', 'ever', 'deserved'): 1,
#           ('ever', 'deserved', 'better'): 1,
#           ('deserved', 'better', 'class'): 1,
#           ('better', 'class', 'criminal'): 1,
#           ('class', 'criminal', 'phillips'): 1,
#           ('criminal', 'phillips', 'phoenix'): 1,
#           ('phillips', 'phoenix', 'delivered'): 1,
#           ('phoenix', 'delivered', 'dark'): 1,
#           ('delivered', 'dark', 'joker'): 1,
#           ('dark', 'joker', 'dark'): 1,
#           ('joker', 'dark', 'fall'): 1,
#           ('dark', 'fall', 'love'): 1,
#           ('fall', 'love', 'villain'): 1,
#           ('love', 'villain', 'bad'): 1,
#           ('villain', 'bad', 'guys'): 1,
#           ('bad', 'guys', 'always'): 1,
#           ('guys', 'always', 'romantic'): 1,
#           ('always', 'romantic', 'anywayjoaquin'): 1,
#           ('romantic', 'anywayjoaquin', 'phoenix'): 1,
#           ('anywayjoaquin', 'phoenix', 'gives'): 1,
#           ('phoenix', 'gives', 'tour'): 1,
#           ('gives', 'tour', 'de'): 1,
#           ('tour', 'de', 'force'): 1,
#           ('de', 'force', 'performance'): 1,
#           ('force', 'performance', 'fearless'): 1,
#           ('performance', 'fearless', 'stunning'): 1,
#           ('fearless', 'stunning', 'emotional'): 1,
#           ('stunning', 'emotional', 'depth'): 1,
#           ('emotional', 'depth', 'physicality'): 1,
#           ('depth', 'physicality', 'impossible'): 1,
#           ('physicality', 'impossible', 'talk'): 1,
#           ('impossible', 'talk', 'without'): 1,
#           ('talk', 'without', 'referencing'): 1,
#           ('without', 'referencing', 'heath'): 1,
#           ('referencing', 'heath', 'ledgers'): 1,
#           ('heath', 'ledgers', 'oscarwinning'): 1,
#           ('ledgers', 'oscarwinning', 'performance'): 1,
#           ('oscarwinning', 'performance', 'dark'): 1,
#           ('performance', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'widely'): 1,
#           ('knight', 'widely', 'considered'): 1,
#           ('widely', 'considered', 'definitive'): 1,
#           ('considered', 'definitive', 'liveaction'): 1,
#           ('definitive', 'liveaction', 'portrayal'): 1,
#           ('liveaction', 'portrayal', 'joker'): 1,
#           ('portrayal', 'joker', 'lets'): 1,
#           ('joker', 'lets', 'talk'): 1,
#           ('lets', 'talk', 'fact'): 1,
#           ('talk', 'fact', 'everyone'): 1,
#           ('fact', 'everyone', 'going'): 1,
#           ('everyone', 'going', 'stunned'): 1,
#           ('going', 'stunned', 'phoenix'): 1,
#           ('stunned', 'phoenix', 'accomplishes'): 1,
#           ('phoenix', 'accomplishes', 'many'): 1,
#           ('accomplishes', 'many', 'thought'): 1,
#           ('many', 'thought', 'impossible'): 1,
#           ('thought', 'impossible', 'portrayal'): 1,
#           ('impossible', 'portrayal', 'matches'): 1,
#           ('portrayal', 'matches', 'potentially'): 1,
#           ('matches', 'potentially', 'exceeds'): 1,
#           ('potentially', 'exceeds', 'dark'): 1,
#           ('exceeds', 'dark', 'knights'): 1,
#           ('dark', 'knights', 'clown'): 1,
#           ('knights', 'clown', 'prince'): 1,
#           ('clown', 'prince', 'crimelet'): 1,
#           ('prince', 'crimelet', 'start'): 1,
#           ('crimelet', 'start', 'saying'): 1,
#           ('start', 'saying', 'joaquin'): 1,
#           ('saying', 'joaquin', 'phoneix'): 1,
#           ('joaquin', 'phoneix', 'doesnt'): 1,
#           ('phoneix', 'doesnt', 'get'): 1,
#           ('doesnt', 'get', 'oscar'): 2,
#           ('get', 'oscar', 'movie'): 1,
#           ('oscar', 'movie', 'oscars'): 1,
#           ('movie', 'oscars', 'cancelled'): 1,
#           ('oscars', 'cancelled', 'phoneix'): 1,
#           ('cancelled', 'phoneix', 'amazing'): 1,
#           ('phoneix', 'amazing', 'mightve'): 1,
#           ('amazing', 'mightve', 'heard'): 1,
#           ('mightve', 'heard', 'every'): 1,
#           ('heard', 'every', 'review'): 1,
#           ('every', 'review', 'ever'): 1,
#           ('review', 'ever', 'todd'): 1,
#           ('ever', 'todd', 'phillips'): 1,
#           ('todd', 'phillips', 'best'): 1,
#           ('phillips', 'best', 'story'): 1,
#           ('best', 'story', 'lines'): 1,
#           ('story', 'lines', 'takes'): 1,
#           ('lines', 'takes', 'visuals'): 1,
#           ('takes', 'visuals', 'breathtaking'): 1,
#           ('visuals', 'breathtaking', 'score'): 1,
#           ('breathtaking', 'score', 'omg'): 1,
#           ('score', 'omg', 'score'): 1,
#           ('omg', 'score', 'every'): 1,
#           ('score', 'every', 'time'): 1,
#           ('every', 'time', 'score'): 1,
#           ('time', 'score', 'came'): 1,
#           ('score', 'came', 'felt'): 1,
#           ('came', 'felt', 'uncomfortable'): 1,
#           ('felt', 'uncomfortable', 'like'): 1,
#           ('uncomfortable', 'like', 'something'): 1,
#           ('like', 'something', 'horrible'): 1,
#           ('something', 'horrible', 'happen'): 1,
#           ('horrible', 'happen', 'great'): 1,
#           ('happen', 'great', 'inspirations'): 1,
#           ('great', 'inspirations', 'taxi'): 1,
#           ('inspirations', 'taxi', 'driver'): 1,
#           ('taxi', 'driver', 'king'): 4,
#           ('driver', 'king', 'comedy'): 4,
#           ('king', 'comedy', 'add'): 1,
#           ('comedy', 'add', 'much'): 1,
#           ('add', 'much', 'movie'): 1,
#           ('much', 'movie', 'got'): 1,
#           ('movie', 'got', 'honest'): 1,
#           ('got', 'honest', 'scenes'): 1,
#           ('honest', 'scenes', 'violent'): 1,
#           ('scenes', 'violent', 'disturbing'): 1,
#           ('violent', 'disturbing', 'honestly'): 1,
#           ('disturbing', 'honestly', 'expected'): 1,
#           ('honestly', 'expected', 'wayyyy'): 1,
#           ('expected', 'wayyyy', 'violent'): 1,
#           ('wayyyy', 'violent', 'controversy'): 1,
#           ('violent', 'controversy', 'going'): 1,
#           ('controversy', 'going', 'overall'): 1,
#           ('going', 'overall', 'movie'): 1,
#           ('overall', 'movie', 'great'): 1,
#           ('movie', 'great', 'come'): 1,
#           ('great', 'come', 'oscar'): 1,
#           ('come', 'oscar', 'season'): 1,
#           ('oscar', 'season', 'needs'): 1,
#           ('season', 'needs', 'nominated'): 1,
#           ('needs', 'nominated', 'best'): 1,
#           ('nominated', 'best', 'picture'): 1,
#           ('best', 'picture', 'screenplay'): 1,
#           ('picture', 'screenplay', 'cinematography'): 1,
#           ('screenplay', 'cinematography', 'actor'): 1,
#           ('cinematography', 'actor', 'score'): 1,
#           ('actor', 'score', 'directorget'): 1,
#           ('score', 'directorget', 'people'): 1,
#           ('directorget', 'people', 'hate'): 1,
#           ('people', 'hate', 'political'): 1,
#           ('hate', 'political', 'message'): 1,
#           ('political', 'message', 'people'): 1,
#           ('message', 'people', 'think'): 1,
#           ('people', 'think', 'need'): 1,
#           ('think', 'need', 'get'): 1,
#           ('need', 'get', 'empathy'): 1,
#           ('get', 'empathy', 'arthurs'): 1,
#           ('empathy', 'arthurs', 'madness'): 1,
#           ('arthurs', 'madness', 'come'): 1,
#           ('madness', 'come', 'point'): 1,
#           ('come', 'point', 'never'): 1,
#           ('point', 'never', 'enjoy'): 1,
#           ('never', 'enjoy', 'masterpiece'): 1,
#           ('enjoy', 'masterpiece', 'joaquin'): 1,
#           ('masterpiece', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'todd'): 2,
#           ('phoenix', 'todd', 'phillips'): 2,
#           ('todd', 'phillips', 'overdid'): 1,
#           ('phillips', 'overdid', 'movie'): 1,
#           ('overdid', 'movie', 'actingmusic'): 1,
#           ('movie', 'actingmusic', 'cinematography'): 1,
#           ('actingmusic', 'cinematography', 'amazing'): 1,
#           ('cinematography', 'amazing', 'please'): 1,
#           ('amazing', 'please', 'enjoy'): 1,
#           ('please', 'enjoy', 'movie'): 1,
#           ('enjoy', 'movie', 'without'): 1,
#           ('movie', 'without', 'overthinkingseen'): 1,
#           ('without', 'overthinkingseen', 'joker'): 1,
#           ('overthinkingseen', 'joker', 'yesterday'): 1,
#           ('joker', 'yesterday', 'venice'): 1,
#           ('yesterday', 'venice', 'early'): 1,
#           ('venice', 'early', 'illfated'): 1,
#           ('early', 'illfated', 'screening'): 1,
#           ('illfated', 'screening', 'trouble'): 1,
#           ('screening', 'trouble', 'audio'): 1,
#           ('trouble', 'audio', 'lead'): 1,
#           ('audio', 'lead', 'nearhour'): 1,
#           ('lead', 'nearhour', 'delay'): 1,
#           ('nearhour', 'delay', 'definitely'): 1,
#           ('delay', 'definitely', 'worth'): 1,
#           ('definitely', 'worth', 'itjoker'): 1,
#           ('worth', 'itjoker', 'deserved'): 1,
#           ('itjoker', 'deserved', 'presented'): 1,
#           ('deserved', 'presented', 'venice'): 1,
#           ('presented', 'venice', 'film'): 1,
#           ('venice', 'film', 'festival'): 1,
#           ('film', 'festival', 'event'): 1,
#           ('festival', 'event', 'regards'): 1,
#           ('event', 'regards', 'cinema'): 1,
#           ('regards', 'cinema', 'form'): 1,
#           ('cinema', 'form', 'art'): 1,
#           ('form', 'art', 'film'): 1,
#           ('art', 'film', 'far'): 1,
#           ('film', 'far', 'blockbuster'): 1,
#           ('far', 'blockbuster', 'mere'): 1,
#           ('blockbuster', 'mere', 'entertainer'): 1,
#           ('mere', 'entertainer', 'movie'): 1,
#           ('entertainer', 'movie', 'films'): 1,
#           ('movie', 'films', 'genre'): 1,
#           ('films', 'genre', 'areit'): 1,
#           ('genre', 'areit', 'focuses'): 1,
#           ('areit', 'focuses', 'psyche'): 1,
#           ('focuses', 'psyche', 'main'): 1,
#           ('psyche', 'main', 'character'): 1,
#           ('main', 'character', 'slowly'): 1,
#           ('character', 'slowly', 'crumbles'): 1,
#           ('slowly', 'crumbles', 'pressure'): 1,
#           ('crumbles', 'pressure', 'society'): 1,
#           ('pressure', 'society', 'thus'): 1,
#           ('society', 'thus', 'joaquin'): 1,
#           ('thus', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'wonderful'): 1,
#           ('phoenix', 'wonderful', 'performance'): 1,
#           ('wonderful', 'performance', 'earning'): 1,
#           ('performance', 'earning', 'almost'): 1,
#           ('earning', 'almost', 'surely'): 1,
#           ('almost', 'surely', 'nomination'): 1,
#           ('surely', 'nomination', 'oscars'): 1,
#           ('nomination', 'oscars', 'least'): 1,
#           ('oscars', 'least', 'take'): 1,
#           ('least', 'take', 'joker'): 1,
#           ('take', 'joker', 'differs'): 1,
#           ('joker', 'differs', 'ledgers'): 1,
#           ('differs', 'ledgers', 'id'): 1,
#           ('ledgers', 'id', 'say'): 1,
#           ('id', 'say', 'equally'): 1,
#           ('say', 'equally', 'good'): 1,
#           ('equally', 'good', 'main'): 1,
#           ('good', 'main', 'difference'): 1,
#           ('main', 'difference', 'might'): 1,
#           ('difference', 'might', 'ledgers'): 1,
#           ('might', 'ledgers', 'joker'): 1,
#           ('ledgers', 'joker', 'rational'): 1,
#           ('joker', 'rational', 'acts'): 1,
#           ('rational', 'acts', 'insane'): 1,
#           ('acts', 'insane', 'phoenixs'): 1,
#           ('insane', 'phoenixs', 'insane'): 1,
#           ('phoenixs', 'insane', 'rootdespite'): 1,
#           ('insane', 'rootdespite', 'movie'): 1,
#           ('rootdespite', 'movie', 'superhero'): 1,
#           ('movie', 'superhero', 'villain'): 1,
#           ('superhero', 'villain', 'joker'): 1,
#           ('villain', 'joker', 'much'): 1,
#           ('joker', 'much', 'superior'): 1,
#           ('much', 'superior', 'movies'): 1,
#           ('superior', 'movies', 'genre'): 1,
#           ('movies', 'genre', 'id'): 1,
#           ('genre', 'id', 'exclude'): 1,
#           ('id', 'exclude', 'dark'): 1,
#           ('exclude', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'trilogy'): 3,
#           ('knight', 'trilogy', 'joker'): 1,
#           ('trilogy', 'joker', 'easily'): 1,
#           ('joker', 'easily', 'good'): 1,
#           ('easily', 'good', 'nolans'): 1,
#           ('good', 'nolans', 'movies'): 1,
#           ('nolans', 'movies', 'least'): 1,
#           ('movies', 'least', 'close'): 1,
#           ('least', 'close', 'smallscaled'): 1,
#           ('close', 'smallscaled', 'film'): 1,
#           ('smallscaled', 'film', 'distinct'): 1,
#           ('film', 'distinct', 'style'): 1,
#           ('distinct', 'style', 'cinematography'): 1,
#           ('style', 'cinematography', 'can'): 1,
#           ('cinematography', 'can', 'not'): 1,
#           ('can', 'not', 'appreciated'): 1,
#           ('not', 'appreciated', 'set'): 1,
#           ('appreciated', 'set', 'cinephile'): 1,
#           ('set', 'cinephile', 'references'): 1,
#           ('cinephile', 'references', 'however'): 1,
#           ('references', 'however', 'feel'): 1,
#           ('however', 'feel', 'forced'): 1,
#           ('feel', 'forced', 'overly'): 1,
#           ('forced', 'overly', 'opressive'): 1,
#           ('overly', 'opressive', 'notable'): 1,
#           ('opressive', 'notable', 'similarities'): 1,
#           ('notable', 'similarities', 'scorseses'): 1,
#           ('similarities', 'scorseses', 'taxi'): 1,
#           ('scorseses', 'taxi', 'driver'): 1,
#           ('king', 'comedy', 'also'): 1,
#           ('comedy', 'also', 'chaplins'): 1,
#           ('also', 'chaplins', 'modern'): 1,
#           ('chaplins', 'modern', 'times'): 1,
#           ('modern', 'times', 'somewhat'): 1,
#           ('times', 'somewhat', 'referencedi'): 1,
#           ('somewhat', 'referencedi', 'eager'): 1,
#           ('referencedi', 'eager', 'see'): 1,
#           ('eager', 'see', 'noncomedic'): 1,
#           ('see', 'noncomedic', 'efforts'): 1,
#           ('noncomedic', 'efforts', 'todd'): 1,
#           ('efforts', 'todd', 'phillips'): 1,
#           ('todd', 'phillips', 'movie'): 1,
#           ('phillips', 'movie', 'far'): 1,
#           ('movie', 'far', 'probably'): 1,
#           ('far', 'probably', 'best'): 1,
#           ('probably', 'best', '2019'): 1,
#           ('best', '2019', 'worst'): 1,
#           ('2019', 'worst', 'contested'): 1,
#           ('worst', 'contested', 'far'): 1,
#           ('contested', 'far', 'dolor'): 1,
#           ('far', 'dolor', 'gloria'): 1,
#           ('dolor', 'gloria', 'upon'): 1,
#           ('gloria', 'upon', 'time'): 1,
#           ('upon', 'time', 'hollywood'): 2,
#           ('time', 'hollywood', 'convincingsad'): 1,
#           ('hollywood', 'convincingsad', 'joaquin'): 1,
#           ('convincingsad', 'joaquin', 'missed'): 1,
#           ('joaquin', 'missed', 'oscar'): 1,
#           ('missed', 'oscar', 'gladiator'): 1,
#           ('oscar', 'gladiator', 'compelling'): 1,
#           ('gladiator', 'compelling', 'villain'): 1,
#           ('compelling', 'villain', 'quite'): 1,
#           ('villain', 'quite', 'confident'): 1,
#           ('quite', 'confident', 'win'): 1,
#           ('confident', 'win', 'joker'): 1,
#           ('win', 'joker', 'damn'): 1,
#           ('joker', 'damn', 'movie'): 1,
#           ('damn', 'movie', 'keeps'): 1,
#           ('movie', 'keeps', 'u'): 1,
#           ('keeps', 'u', 'toes'): 1,
#           ('u', 'toes', 'time'): 1,
#           ('toes', 'time', 'unpredictable'): 1,
#           ('time', 'unpredictable', 'storyline'): 1,
#           ('unpredictable', 'storyline', 'really'): 1,
#           ('storyline', 'really', 'deep'): 1,
#           ('really', 'deep', 'interesting'): 1,
#           ('deep', 'interesting', 'plot'): 1,
#           ('interesting', 'plot', 'forget'): 1,
#           ('plot', 'forget', 'mention'): 1,
#           ('forget', 'mention', 'acting'): 1,
#           ('mention', 'acting', 'damn'): 1,
#           ('acting', 'damn', 'niro'): 1,
#           ('damn', 'niro', 'joaquin'): 1,
#           ('niro', 'joaquin', 'teach'): 1,
#           ('joaquin', 'teach', 'u'): 1,
#           ('teach', 'u', 'really'): 1,
#           ('u', 'really', '5'): 1,
#           ('really', '5', 'star'): 1,
#           ('5', 'star', 'acting'): 1,
#           ('star', 'acting', 'enjoy'): 1,
#           ('acting', 'enjoy', 'movie'): 1,
#           ('enjoy', 'movie', 'get'): 1,
#           ('movie', 'get', 'wine'): 1,
#           ('get', 'wine', 'hand'): 1,
#           ('wine', 'hand', 'close'): 1,
#           ('hand', 'close', 'curtains'): 1,
#           ('close', 'curtains', 'turn'): 1,
#           ('curtains', 'turn', 'ur'): 1,
#           ('turn', 'ur', 'cellphones'): 1,
#           ('ur', 'cellphones', 'put'): 1,
#           ('cellphones', 'put', 'disturb'): 1,
#           ('put', 'disturb', 'sign'): 1,
#           ('disturb', 'sign', 'ur'): 1,
#           ('sign', 'ur', 'door'): 1,
#           ('ur', 'door', 'best'): 1,
#           ('door', 'best', 'dark'): 1,
#           ('best', 'dark', 'thriller'): 1,
#           ('dark', 'thriller', 'suspense'): 1,
#           ('thriller', 'suspense', 'movie'): 1,
#           ('suspense', 'movie', 'get'): 1,
#           ('movie', 'get', 'experiencewatched'): 1,
#           ('get', 'experiencewatched', 'joker'): 1,
#           ('experiencewatched', 'joker', 'venice'): 1,
#           ('joker', 'venice', 'say'): 1,
#           ('venice', 'say', 'joaquin'): 1,
#           ('say', 'joaquin', 'doesnt'): 1,
#           ('joaquin', 'doesnt', 'get'): 1,
#           ('get', 'oscar', 'year'): 1,
#           ('oscar', 'year', 'something'): 1,
#           ('year', 'something', 'wrong'): 1,
#           ('something', 'wrong', 'world'): 1,
#           ('wrong', 'world', 'perfomance'): 1,
#           ('world', 'perfomance', 'jawdropping'): 1,
#           ('perfomance', 'jawdropping', 'glues'): 1,
#           ('jawdropping', 'glues', 'screen'): 1,
#           ('glues', 'screen', 'doesnt'): 1,
#           ('screen', 'doesnt', 'let'): 1,
#           ('doesnt', 'let', 'go'): 1,
#           ('let', 'go', 'till'): 1,
#           ('go', 'till', 'end'): 1,
#           ('till', 'end', 'story'): 1,
#           ('end', 'story', 'good'): 1,
#           ('story', 'good', 'interesting'): 1,
#           ('good', 'interesting', 'connections'): 1,
#           ('interesting', 'connections', 'batman'): 1,
#           ('connections', 'batman', 'loreespecially'): 1,
#           ('batman', 'loreespecially', 'one'): 1,
#           ('loreespecially', 'one', 'cant'): 1,
#           ('one', 'cant', 'guess'): 1,
#           ('cant', 'guess', 'trailers'): 1,
#           ('guess', 'trailers', 'scenes'): 1,
#           ('trailers', 'scenes', 'tense'): 1,
#           ('scenes', 'tense', 'wellacted'): 1,
#           ('tense', 'wellacted', 'imaginative'): 1,
#           ('wellacted', 'imaginative', 'push'): 1,
#           ('imaginative', 'push', 'movie'): 1,
#           ('push', 'movie', '10'): 1,
#           ('movie', '10', 'cinematography'): 1,
#           ('10', 'cinematography', 'direction'): 1,
#           ('cinematography', 'direction', 'great'): 1,
#           ('direction', 'great', 'todd'): 1,
#           ('great', 'todd', 'proven'): 1,
#           ('todd', 'proven', 'director'): 1,
#           ('proven', 'director', 'robert'): 1,
#           ('director', 'robert', 'also'): 1,
#           ('robert', 'also', 'good'): 1,
#           ('also', 'good', 'small'): 1,
#           ('good', 'small', 'role'): 1,
#           ('small', 'role', 'definitely'): 1,
#           ('role', 'definitely', 'see'): 1,
#           ('definitely', 'see', 'soon'): 1,
#           ('see', 'soon', 'octobermovie'): 1,
#           ('soon', 'octobermovie', 'causes'): 1,
#           ('octobermovie', 'causes', 'audience'): 1,
#           ('causes', 'audience', 'consider'): 1,
#           ('audience', 'consider', 'many'): 1,
#           ('consider', 'many', 'topics'): 1,
#           ('many', 'topics', 'morality'): 1,
#           ('topics', 'morality', 'particularly'): 1,
#           ('morality', 'particularly', 'poor'): 1,
#           ('particularly', 'poor', 'choices'): 1,
#           ('poor', 'choices', 'made'): 1,
#           ('choices', 'made', 'joker'): 1,
#           ('made', 'joker', 'joker'): 1,
#           ('joker', 'joker', 'relatable'): 1,
#           ('joker', 'relatable', 'movie'): 1,
#           ('relatable', 'movie', 'antagonists'): 1,
#           ('movie', 'antagonists', 'usually'): 1,
#           ('antagonists', 'usually', 'think'): 1,
#           ('usually', 'think', 'gives'): 1,
#           ('think', 'gives', 'realistic'): 1,
#           ('gives', 'realistic', 'view'): 1,
#           ('realistic', 'view', 'bad'): 1,
#           ('view', 'bad', 'people'): 1,
#           ('bad', 'people', 'usually'): 1,
#           ('people', 'usually', '100'): 1,
#           ('usually', '100', 'bad'): 1,
#           ('100', 'bad', 'ways'): 1,
#           ('bad', 'ways', 'society'): 1,
#           ('ways', 'society', 'often'): 1,
#           ('society', 'often', 'judges'): 1,
#           ('often', 'judges', 'important'): 1,
#           ('judges', 'important', 'know'): 1,
#           ('important', 'know', 'sympathize'): 1,
#           ('know', 'sympathize', 'joker'): 1,
#           ('sympathize', 'joker', 'towards'): 1,
#           ('joker', 'towards', 'beginning'): 1,
#           ('towards', 'beginning', 'movie'): 1,
#           ('beginning', 'movie', 'needs'): 1,
#           ('movie', 'needs', 'identified'): 1,
#           ('needs', 'identified', 'threat'): 1,
#           ('identified', 'threat', 'begins'): 1,
#           ('threat', 'begins', 'making'): 1,
#           ('begins', 'making', 'certain'): 1,
#           ('making', 'certain', 'bad'): 1,
#           ('certain', 'bad', 'choices'): 1,
#           ('bad', 'choices', 'movie'): 1,
#           ('choices', 'movie', 'suitable'): 1,
#           ('movie', 'suitable', 'adults'): 1,
#           ('suitable', 'adults', 'willing'): 1,
#           ('adults', 'willing', 'pick'): 1,
#           ('willing', 'pick', 'apart'): 1,
#           ('pick', 'apart', 'think'): 1,
#           ('apart', 'think', 'critically'): 1,
#           ('think', 'critically', 'isnt'): 1,
#           ('critically', 'isnt', 'light'): 1,
#           ('isnt', 'light', 'amusement'): 1,
#           ('light', 'amusement', 'substance'): 1,
#           ('amusement', 'substance', 'makes'): 1,
#           ('substance', 'makes', 'goodif'): 1,
#           ('makes', 'goodif', 'arent'): 1,
#           ('goodif', 'arent', 'able'): 1,
#           ('arent', 'able', 'ponder'): 1,
#           ('able', 'ponder', 'underlying'): 1,
#           ('ponder', 'underlying', 'themes'): 1,
#           ('underlying', 'themes', 'handed'): 1,
#           ('themes', 'handed', 'thoughts'): 1,
#           ('handed', 'thoughts', 'isnt'): 1,
#           ('thoughts', 'isnt', 'best'): 1,
#           ('isnt', 'best', 'movieacting'): 1,
#           ('best', 'movieacting', 'cinematography'): 1,
#           ('movieacting', 'cinematography', 'sound'): 1,
#           ('cinematography', 'sound', 'design'): 1,
#           ('sound', 'design', 'script'): 1,
#           ('design', 'script', 'phenomenal'): 1,
#           ('script', 'phenomenal', 'movie'): 1,
#           ('phenomenal', 'movie', 'triumph'): 1,
#           ('movie', 'triumph', 'joaquin'): 1,
#           ('triumph', 'joaquin', 'pheonix'): 1,
#           ('joaquin', 'pheonix', 'deserves'): 1,
#           ('pheonix', 'deserves', 'oscar'): 1,
#           ('deserves', 'oscar', 'win'): 1,
#           ('oscar', 'win', 'tbhmovie'): 1,
#           ('win', 'tbhmovie', 'affects'): 1,
#           ('tbhmovie', 'affects', 'way'): 1,
#           ('affects', 'way', 'makes'): 1,
#           ('way', 'makes', 'physically'): 1,
#           ('makes', 'physically', 'painful'): 1,
#           ('physically', 'painful', 'experience'): 1,
#           ('painful', 'experience', 'good'): 1,
#           ('experience', 'good', 'waystop'): 1,
#           ('good', 'waystop', 'watching'): 1,
#           ('waystop', 'watching', 'movies'): 1,
#           ('watching', 'movies', 'joaquin'): 1,
#           ('movies', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'awarded'): 1,
#           ('phoenix', 'awarded', 'oscar'): 1,
#           ('awarded', 'oscar', 'tremendous'): 1,
#           ('oscar', 'tremendous', 'actingquit'): 1,
#           ('tremendous', 'actingquit', 'relying'): 1,
#           ('actingquit', 'relying', 'critic'): 1,
#           ('relying', 'critic', 'reviews'): 1,
#           ('critic', 'reviews', 'years'): 1,
#           ('reviews', 'years', 'ago'): 1,
#           ('years', 'ago', 'noticed'): 1,
#           ('ago', 'noticed', 'movie'): 1,
#           ('noticed', 'movie', 'critics'): 1,
#           ('movie', 'critics', 'ratings'): 1,
#           ('critics', 'ratings', 'low'): 1,
#           ('ratings', 'low', 'viewer'): 1,
#           ('low', 'viewer', 'ratings'): 1,
#           ('viewer', 'ratings', 'high'): 1,
#           ('ratings', 'high', 'said'): 1,
#           ('high', 'said', 'point'): 1,
#           ('said', 'point', 'critic'): 1,
#           ('point', 'critic', 'movie'): 1,
#           ('critic', 'movie', 'oh'): 1,
#           ('movie', 'oh', 'wrong'): 1,
#           ('oh', 'wrong', 'went'): 1,
#           ('wrong', 'went', 'saw'): 1,
#           ('went', 'saw', 'tonite'): 1,
#           ('saw', 'tonite', 'mom'): 1,
#           ('tonite', 'mom', 'went'): 1,
#           ('mom', 'went', 'skeptical'): 1,
#           ('went', 'skeptical', 'w'): 1,
#           ('skeptical', 'w', 'low'): 1,
#           ('w', 'low', 'expectations'): 1,
#           ('low', 'expectations', 'knew'): 1,
#           ('expectations', 'knew', 'expect'): 1,
#           ('knew', 'expect', 'typical'): 1,
#           ('expect', 'typical', 'super'): 1,
#           ('typical', 'super', 'hero'): 1,
#           ('super', 'hero', 'movie'): 2,
#           ('hero', 'movie', 'got'): 1,
#           ('movie', 'got', 'masterpiece'): 1,
#           ('got', 'masterpiece', 'went'): 1,
#           ('masterpiece', 'went', 'expecting'): 1,
#           ('went', 'expecting', 'sheer'): 1,
#           ('expecting', 'sheer', 'boredom'): 1,
#           ('sheer', 'boredom', 'instead'): 1,
#           ('boredom', 'instead', 'edge'): 1,
#           ('instead', 'edge', 'seat'): 1,
#           ('edge', 'seat', 'whole'): 1,
#           ('seat', 'whole', 'time'): 1,
#           ('whole', 'time', 'action'): 1,
#           ('time', 'action', 'edge'): 1,
#           ('action', 'edge', 'seat'): 1,
#           ('edge', 'seat', 'fear'): 1,
#           ('seat', 'fear', 'may'): 1,
#           ('fear', 'may', 'say'): 1,
#           ('may', 'say', 'next'): 1,
#           ('say', 'next', 'edge'): 1,
#           ('next', 'edge', 'seat'): 1,
#           ('edge', 'seat', 'see'): 1,
#           ('seat', 'see', 'character'): 1,
#           ('see', 'character', 'evolve'): 1,
#           ('character', 'evolve', 'know'): 1,
#           ('evolve', 'know', '1'): 1,
#           ('know', '1', 'villain'): 1,
#           ('1', 'villain', 'batman'): 1,
#           ('villain', 'batman', 'beyond'): 1,
#           ('batman', 'beyond', 'genius'): 1,
#           ('beyond', 'genius', 'joaquin'): 1,
#           ('genius', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'true'): 1,
#           ('phoenix', 'true', 'master'): 1,
#           ('true', 'master', 'perfecting'): 1,
#           ('master', 'perfecting', 'art'): 1,
#           ('perfecting', 'art', 'consuming'): 1,
#           ('art', 'consuming', 'character'): 1,
#           ('consuming', 'character', 'may'): 1,
#           ('character', 'may', 'place'): 1,
#           ('may', 'place', 'dont'): 1,
#           ('place', 'dont', 'care'): 1,
#           ('dont', 'care', 'movie'): 1,
#           ('care', 'movie', 'story'): 1,
#           ('movie', 'story', 'acting'): 1,
#           ('story', 'acting', 'directing'): 1,
#           ('acting', 'directing', 'effects'): 1,
#           ('directing', 'effects', 'everyone'): 1,
#           ('effects', 'everyone', 'brought'): 1,
#           ('everyone', 'brought', 'game'): 1,
#           ('brought', 'game', 'jp'): 1,
#           ('game', 'jp', 'definitely'): 1,
#           ('jp', 'definitely', 'deserves'): 1,
#           ('definitely', 'deserves', 'nod'): 1,
#           ('deserves', 'nod', 'win'): 1,
#           ('nod', 'win', 'role'): 1,
#           ('win', 'role', 'comparison'): 1,
#           ('role', 'comparison', 'jack'): 1,
#           ('comparison', 'jack', 'nicholson'): 1,
#           ('jack', 'nicholson', 'heath'): 1,
#           ('nicholson', 'heath', 'ledger'): 1,
#           ('heath', 'ledger', 'actor'): 1,
#           ('ledger', 'actor', 'took'): 1,
#           ('actor', 'took', 'character'): 1,
#           ('took', 'character', 'different'): 1,
#           ('character', 'different', 'levels'): 1,
#           ('different', 'levels', 'different'): 1,
#           ('levels', 'different', 'story'): 1,
#           ('different', 'story', 'points'): 1,
#           ('story', 'points', 'different'): 1,
#           ('points', 'different', 'points'): 1,
#           ('different', 'points', 'time'): 1,
#           ('points', 'time', 'comparison'): 1,
#           ('time', 'comparison', 'would'): 1,
#           ('comparison', 'would', 'feasible'): 1,
#           ('would', 'feasible', 'fair'): 1,
#           ('feasible', 'fair', 'actors'): 1,
#           ('fair', 'actors', 'embraced'): 1,
#           ('actors', 'embraced', 'made'): 1,
#           ('embraced', 'made', 'come'): 1,
#           ('made', 'come', 'life'): 1,
#           ('come', 'life', 'genius'): 1,
#           ('life', 'genius', 'wayneed'): 1,
#           ('genius', 'wayneed', 'say'): 1,
#           ('wayneed', 'say', 'everything'): 1,
#           ('say', 'everything', 'movie'): 1,
#           ('everything', 'movie', 'masterful'): 1,
#           ('movie', 'masterful', 'every'): 1,
#           ('masterful', 'every', 'single'): 1,
#           ('every', 'single', 'way'): 1,
#           ('single', 'way', 'joker'): 1,
#           ('way', 'joker', 'isnt'): 1,
#           ('joker', 'isnt', 'awesome'): 1,
#           ('isnt', 'awesome', 'comic'): 1,
#           ('awesome', 'comic', 'book'): 1,
#           ('comic', 'book', 'movie'): 5,
#           ('book', 'movie', 'awesome'): 1,
#           ('movie', 'awesome', 'movie'): 1,
#           ('awesome', 'movie', 'period'): 1,
#           ('movie', 'period', 'offers'): 1,
#           ('period', 'offers', 'easy'): 1,
#           ('offers', 'easy', 'answers'): 1,
#           ('easy', 'answers', 'unsettling'): 1,
#           ('answers', 'unsettling', 'questions'): 1,
#           ('unsettling', 'questions', 'raises'): 1,
#           ('questions', 'raises', 'cruel'): 1,
#           ('raises', 'cruel', 'society'): 1,
#           ('cruel', 'society', 'decline'): 1,
#           ('society', 'decline', 'joaquin'): 1,
#           ('decline', 'joaquin', 'phoenixs'): 1,
#           ('joaquin', 'phoenixs', 'fully'): 1,
#           ('phoenixs', 'fully', 'committed'): 1,
#           ('fully', 'committed', 'performance'): 1,
#           ('committed', 'performance', 'todd'): 1,
#           ('performance', 'todd', 'phillips'): 1,
#           ('todd', 'phillips', 'masterful'): 1,
#           ('phillips', 'masterful', 'albeit'): 1,
#           ('masterful', 'albeit', 'loose'): 1,
#           ('albeit', 'loose', 'reinvention'): 1,
#           ('loose', 'reinvention', 'dc'): 1,
#           ('reinvention', 'dc', 'source'): 1,
#           ('dc', 'source', 'material'): 1,
#           ('source', 'material', 'make'): 1,
#           ('material', 'make', 'joker'): 1,
#           ('make', 'joker', 'film'): 1,
#           ('joker', 'film', 'leave'): 1,
#           ('film', 'leave', 'comic'): 1,
#           ('leave', 'comic', 'book'): 1,
#           ('comic', 'book', 'fans'): 1,
#           ('book', 'fans', 'nonfans'): 1,
#           ('fans', 'nonfans', 'alike'): 1,
#           ('nonfans', 'alike', 'disturbed'): 1,
#           ('alike', 'disturbed', 'moved'): 1,
#           ('disturbed', 'moved', 'right'): 1,
#           ('moved', 'right', 'waysmovie'): 1,
#           ('right', 'waysmovie', 'answers'): 1,
#           ('waysmovie', 'answers', 'questionwhat'): 1,
#           ('answers', 'questionwhat', 'joker'): 1,
#           ('questionwhat', 'joker', 'real'): 1,
#           ('joker', 'real', 'life'): 1,
#           ('real', 'life', 'character'): 1,
#           ('life', 'character', 'great'): 1,
#           ('character', 'great', 'deep'): 1,
#           ('great', 'deep', 'moving'): 1,
#           ('deep', 'moving', 'story'): 1,
#           ('moving', 'story', 'life'): 1,
#           ('story', 'life', 'journey'): 1,
#           ('life', 'journey', 'man'): 1,
#           ('journey', 'man', 'whos'): 1,
#           ('man', 'whos', 'suffering'): 1,
#           ('whos', 'suffering', 'psychological'): 1,
#           ('suffering', 'psychological', 'issues'): 1,
#           ('psychological', 'issues', 'neglect'): 1,
#           ('issues', 'neglect', 'bullying'): 1,
#           ('neglect', 'bullying', 'rudeness'): 1,
#           ('bullying', 'rudeness', 'human'): 1,
#           ('rudeness', 'human', 'push'): 1,
#           ('human', 'push', 'man'): 1,
#           ('push', 'man', 'complete'): 1,
#           ('man', 'complete', 'madnessalthough'): 1,
#           ('complete', 'madnessalthough', 'accurate'): 1,
#           ('madnessalthough', 'accurate', 'comic'): 1,
#           ('accurate', 'comic', 'book'): 1,
#           ('comic', 'book', 'adaptation'): 1,
#           ('book', 'adaptation', 'tv'): 1,
#           ('adaptation', 'tv', 'series'): 1,
#           ('tv', 'series', 'movie'): 1,
#           ('series', 'movie', 'yet'): 1,
#           ('movie', 'yet', 'fresh'): 1,
#           ...})

# %%
#bigrams
result_bigrams = nltk.bigrams(words)
import re
from itertools import tee, islice
import collections
def ngrams(lst, n):
  tlst = lst
  while True:
    a, b = tee(tlst)
    l = tuple(islice(a, n))
    if len(l) == n:
      yield l
      next(b)
      tlst = b
    else:
      break
line2 = collections.Counter(ngrams(line.split(), 2))
print(line2)
# Out:
# Counter({('joaquin', 'phoenix'): 24, ('comic', 'book'): 18, ('taxi', 'driver'): 18, ('dark', 'knight'): 14, ('todd', 'phillips'): 11, ('heath', 'ledger'): 10, ('one', 'best'): 8, ('king', 'comedy'): 8, ('felt', 'like'): 8, ('origin', 'story'): 8, ('mental', 'illness'): 8, ('joker', 'movie'): 7, ('arthur', 'fleck'): 7, ('mental', 'health'): 7, ('robert', 'de'): 6, ('de', 'niro'): 6, ('2', 'hours'): 6, ('character', 'development'): 5, ('feel', 'like'): 5, ('first', 'time'): 5, ('heath', 'ledgers'): 5, ('take', 'joker'): 5, ('book', 'movie'): 5, ('superhero', 'movies'): 5, ('dont', 'get'): 5, ('character', 'study'): 5, ('superhero', 'movie'): 4, ('driver', 'king'): 4, ('movie', 'far'): 4, ('made', 'joker'): 4, ('super', 'hero'): 4, ('take', 'character'): 4, ('long', 'time'): 4, ('movie', 'movie'): 4, ('movie', 'even'): 4, ('phoenix', 'joker'): 4, ('get', 'hype'): 4, ('5', 'minutes'): 4, ('mentally', 'unstable'): 4, ('batman', 'universe'): 4, ('movie', 'also'): 4, ('phoenixs', 'performance'): 4, ('films', 'like'): 4, ('much', 'better'): 4, ('movie', 'dark'): 4, ('throughout', 'film'): 3, ('joaquins', 'performance'): 3, ('see', 'movie'): 3, ('phoenix', 'gives'): 3, ('clown', 'prince'): 3, ('much', 'movie'): 3, ('movie', 'great'): 3, ('film', 'far'): 3, ('ledgers', 'joker'): 3, ('knight', 'trilogy'): 3, ('deserves', 'oscar'): 3, ('hero', 'movie'): 3, ('edge', 'seat'): 3, ('joker', 'film'): 3, ('real', 'life'): 3, ('joker', 'character'): 3, ('great', 'movie'): 3, ('movie', 'joker'): 3, ('best', 'performances'): 3, ('ive', 'ever'): 3, ('joker', 'joaquin'): 3, ('screen', 'time'): 3, ('would', 'like'): 3, ('movie', 'absolutely'): 3, ('murray', 'franklin'): 3, ('couldnt', 'help'): 3, ('movie', 'made'): 3, ('todd', 'philips'): 3, ('health', 'issues'): 3, ('joker', 'one'): 3, ('good', 'movie'): 3, ('movie', 'good'): 3, ('film', 'year'): 3, ('really', 'good'): 3, ('make', 'sense'): 3, ('oscar', 'worthy'): 3, ('performance', 'joaquin'): 3, ('know', 'love'): 3, ('throughout', 'movie'): 3, ('dont', 'need'): 3, ('good', 'story'): 3, ('seen', 'many'): 3, ('made', 'feel'): 3, ('movie', 'one'): 3, ('like', 'dark'): 3, ('say', 'movie'): 3, ('dont', 'see'): 3, ('completely', 'different'): 3, ('become', 'joker'): 3, ('things', 'happen'): 3, ('joker', 'would'): 3, ('dark', 'gritty'): 3, ('best', 'movies'): 3, ('good', 'bad'): 3, ('dc', 'comics'): 3, ('mentally', 'ill'): 3, ('many', 'times'): 3, ('beginning', 'end'): 3, ('seem', 'like'): 3, ('liked', 'movie'): 3, ('much', 'character'): 3, ('ive', 'seen'): 3, ('dont', 'know'): 3, ('good', 'thing'): 3, ('thing', 'movie'): 3, ('fight', 'club'): 3, ('thomas', 'wayne'): 3, ('rich', 'people'): 3, ('watch', 'movie'): 3, ('film', 'thought'): 2, ('best', 'joker'): 2, ('joker', 'origin'): 2, ('blown', 'away'): 2, ('feel', 'sorry'): 2, ('lot', 'people'): 2, ('make', 'feel'): 2, ('making', 'feel'): 2, ('best', 'films'): 2, ('cinematography', 'music'): 2, ('wake', 'call'): 2, ('joker', 'first'): 2, ('say', 'least'): 2, ('comic', 'movie'): 2, ('phillips', 'phoenix'): 2, ('emotional', 'depth'): 2, ('doesnt', 'get'): 2, ('get', 'oscar'): 2, ('every', 'time'): 2, ('movie', 'got'): 2, ('people', 'think'): 2, ('think', 'need'): 2, ('need', 'get'): 2, ('phoenix', 'todd'): 2, ('enjoy', 'movie'): 2, ('movie', 'without'): 2, ('film', 'festival'): 2, ('character', 'slowly'): 2, ('id', 'say'): 2, ('probably', 'best'): 2, ('upon', 'time'): 2, ('time', 'hollywood'): 2, ('movie', 'get'): 2, ('go', 'till'): 2, ('definitely', 'see'): 2, ('choices', 'made'): 2, ('reviews', 'years'): 2, ('expect', 'typical'): 2, ('whole', 'time'): 2, ('acting', 'directing'): 2, ('every', 'single'): 2, ('joaquin', 'phoenixs'): 2, ('prince', 'crime'): 2, ('performance', 'joker'): 2, ('feel', 'sympathy'): 2, ('one', 'another'): 2, ('also', 'interesting'): 2, ('high', 'expectations'): 2, ('joker', 'felt'): 2, ('parts', 'movie'): 2, ('role', 'joker'): 2, ('three', 'people'): 2, ('movie', 'could'): 2, ('performances', 'ive'): 2, ('ever', 'seen'): 2, ('win' ...

# %%
#join bigrams
s1 = ''
for w1,w2 in result_bigrams:
  s1 = s1 + ' ' + w1 + ' ' + w2
list = s1.split()
print(list)
# Out:
# ['person', 'saw', 'saw', 'hype', 'hype', 'claims', 'claims', 'masterpiece', 'masterpiece', 'overreacting', 'overreacting', 'overblown', 'overblown', 'excitement', 'excitement', 'another', 'another', 'joker', 'joker', 'based', 'based', 'film', 'film', 'thought', 'thought', 'looked', 'looked', 'solid', 'solid', 'best', 'best', 'even', 'even', 'bit', 'bit', 'pretentious', 'pretentious', 'trailer', 'trailer', 'say', 'say', 'incredibly', 'incredibly', 'wrong', 'wrong', 'massive', 'massive', 'achievement', 'achievement', 'cinema', 'cinema', 'thats', 'thats', 'extremely', 'extremely', 'rare', 'rare', 'day', 'day', 'age', 'age', 'cgi', 'cgi', 'nonsense', 'nonsense', 'reboots', 'reboots', 'somewhat', 'somewhat', 'reboot', 'reboot', 'sorts', 'sorts', 'standalone', 'standalone', 'origin', 'origin', 'tale', 'tale', 'impeccable', 'impeccable', 'start', 'start', 'finish', 'finish', 'echoes', 'echoes', 'resemblance', 'resemblance', 'best', 'best', 'joker', 'joker', 'origin', 'origin', 'comics', 'comics', 'past', 'past', 'joaquin', 'joaquin', 'bleeds', 'bleeds', 'sweats', 'sweats', 'cries', 'cries', 'every', 'every', 'drop', 'drop', 'magnificently', 'magnificently', 'dedicated', 'dedicated', 'performance', 'performance', 'heath', 'heath', 'ledger', 'ledger', 'would', 'would', 'proud', 'proud', 'undoubtedly', 'undoubtedly', 'greatest', 'greatest', 'acting', 'acting', 'performance', 'performance', 'since', 'since', 'heaths', 'heaths', 'joker', 'joker', 'directing', 'directing', 'writing', 'writing', 'slickly', 'slickly', 'brilliant', 'brilliant', 'bleak', 'bleak', 'settings', 'settings', 'tones', 'tones', 'palpable', 'palpable', 'throughout', 'throughout', 'film', 'film', 'place', 'place', 'blown', 'blown', 'away', 'away', 'every', 'every', 'audience', 'audience', 'member', 'member', 'awestruck', 'awestruck', 'witnessed', 'witnessed', 'film', 'film', 'could', 'could', 'still', 'still', 'transport', 'transport', 'characters', 'characters', 'world', 'world', 'existence', 'existence', 'believe', 'believe', 'hype', 'hype', 'going', 'going', 'revered', 'revered', 'transcending', 'transcending', 'masterpiece', 'masterpiece', 'cinemaevery', 'cinemaevery', 'movie', 'movie', 'comes', 'comes', 'truly', 'truly', 'makes', 'makes', 'impact', 'impact', 'joaquins', 'joaquins', 'performance', 'performance', 'scenography', 'scenography', 'brilliance', 'brilliance', 'grotesque', 'grotesque', 'haunting', 'haunting', 'cringy', 'cringy', 'hard', 'hard', 'watch', 'watch', 'times', 'times', 'mesmerizing', 'mesmerizing', 'wont', 'wont', 'blink', 'blink', 'eye', 'eye', 'watching', 'watching', 'tragic', 'tragic', 'seriously', 'seriously', 'funny', 'funny', 'moments', 'moments', 'emotional', 'emotional', 'rollercoaster', 'rollercoaster', 'sometimes', 'sometimes', 'multiple', 'multiple', 'emotions', 'emotions', 'poppingup', 'poppingup', 'timethis', 'timethis', 'far', 'far', 'typical', 'typical', 'actionriddled', 'actionriddled', 'predictable', 'predictable', 'superhero', 'superhero', 'movie', 'movie', 'proper', 'proper', 'psychological', 'psychological', 'thrillerdrama', 'thrillerdrama', 'single', 'single', 'best', 'best', 'character', 'character', 'development', 'development', 'ever', 'ever', 'seenmovie', 'seenmovie', 'felt', 'felt', 'alone', 'alone', 'isolated', 'isolated', 'truly', 'truly', 'relate', 'relate', 'understand', 'understand', 'motive', 'motive', 'feel', 'feel', 'sorry', 'sorry', 'character', 'character', 'lot', 'lot', 'people', 'people', 'see', 'see', 'movie', 'movie', 'think', 'think', 'encourages', 'encourages', 'violence', 'violence', 'truly', 'truly', 'movie', 'movie', 'encourage', 'encourage', 'every', 'every', 'one', 'one', 'us', 'us', 'become', 'become', 'better', 'better', 'person', 'person', 'treat', 'treat', 'everyone', 'everyone', 'respect', 'respect', 'make', 'make', 'feel', 'feel', 'like', 'like', 'belong', 'belong', 'world', 'world', 'instead', 'instead', 'making', 'making', 'feel', 'feel', 'isolatedtruly', 'isolatedtruly', 'masterpiece', 'mas ...

# %%
for w1,w2 in line2:      #probability
  den = list.count(w1)
  num = line2[(w1,w2)]
  if den == 0:
    break
  prob = num/den
  print(w1,w2,prob)
# Out:
# person saw 0.02564102564102564
# saw hype 0.1
# hype claims 0.038461538461538464
# claims masterpiece 0.25
# masterpiece overreacting 0.021739130434782608
# overreacting overblown 0.5
# overblown excitement 0.5
# excitement another 0.25
# another joker 0.0625
# joker based 0.0032258064516129032
# based film 0.08333333333333333
# film thought 0.013513513513513514
# thought looked 0.041666666666666664
# looked solid 0.1
# solid best 0.25
# best even 0.014705882352941176
# even bit 0.01282051282051282
# bit pretentious 0.0625
# pretentious trailer 0.16666666666666666
# trailer say 0.1
# say incredibly 0.018518518518518517
# incredibly wrong 0.16666666666666666
# wrong massive 0.0625
# massive achievement 0.25
# achievement cinema 0.16666666666666666
# cinema thats 0.038461538461538464
# thats extremely 0.02631578947368421
# extremely rare 0.16666666666666666
# rare day 0.5
# day age 0.08333333333333333
# age cgi 0.5
# cgi nonsense 0.16666666666666666
# nonsense reboots 0.5
# reboots somewhat 0.5
# somewhat reboot 0.07142857142857142
# reboot sorts 0.5
# sorts standalone 0.5
# standalone origin 0.16666666666666666
# origin tale 0.03125
# tale impeccable 0.5
# impeccable start 0.5
# start finish 0.05555555555555555
# finish echoes 0.25
# echoes resemblance 0.5
# resemblance best 0.5
# best joker 0.029411764705882353
# joker origin 0.0064516129032258064
# origin comics 0.03125
# comics past 0.07142857142857142
# past joaquin 0.1
# joaquin bleeds 0.011904761904761904
# bleeds sweats 0.5
# sweats cries 0.5
# cries every 0.16666666666666666
# every drop 0.03571428571428571
# drop magnificently 0.25
# magnificently dedicated 0.5
# dedicated performance 0.5
# performance heath 0.015625
# heath ledger 0.29411764705882354
# ledger would 0.03571428571428571
# would proud 0.013157894736842105
# proud undoubtedly 0.5
# undoubtedly greatest 0.5
# greatest acting 0.1
# acting performance 0.015151515151515152
# performance since 0.015625
# since heaths 0.0625
# heaths joker 0.5
# joker directing 0.0032258064516129032
# directing writing 0.05555555555555555
# writing slickly 0.05555555555555555
# slickly brilliant 0.5
# brilliant bleak 0.05
# bleak settings 0.25
# settings tones 0.5
# tones palpable 0.5
# palpable throughout 0.25
# throughout film 0.13636363636363635
# film place 0.006756756756756757
# place blown 0.16666666666666666
# blown away 0.5
# away every 0.041666666666666664
# every audience 0.03571428571428571
# audience member 0.0625
# member awestruck 0.5
# awestruck witnessed 0.5
# witnessed film 0.5
# film could 0.006756756756756757
# could still 0.020833333333333332
# still transport 0.05555555555555555
# transport characters 0.5
# characters world 0.08333333333333333
# world existence 0.03333333333333333
# existence believe 0.25
# believe hype 0.07142857142857142
# hype going 0.038461538461538464
# going revered 0.03333333333333333
# revered transcending 0.5
# transcending masterpiece 0.5
# masterpiece cinemaevery 0.021739130434782608
# cinemaevery movie 0.5
# movie comes 0.002066115702479339
# comes truly 0.1
# truly makes 0.0625
# makes impact 0.05
# impact joaquins 0.25
# joaquins performance 0.25
# performance scenography 0.015625
# scenography brilliance 0.5
# brilliance grotesque 0.25
# grotesque haunting 0.5
# haunting cringy 0.16666666666666666
# cringy hard 0.5
# hard watch 0.0625
# watch times 0.02
# times mesmerizing 0.045454545454545456
# mesmerizing wont 0.16666666666666666
# wont blink 0.0625
# blink eye 0.5
# eye watching 0.5
# watching tragic 0.03333333333333333
# tragic seriously 0.5
# seriously funny 0.25
# funny moments 0.08333333333333333
# moments emotional 0.05
# emotional rollercoaster 0.1
# rollercoaster sometimes 0.5
# sometimes multiple 0.08333333333333333
# multiple emotions 0.08333333333333333
# emotions poppingup 0.1
# poppingup timethis 0.5
# timethis far 0.5
# far typical 0.02631578947368421
# typical actionriddled 0.125
# actionriddled predictable 0.5
# predictable superhero 0.1
# superhero movie 0.14285714285714285
# movie proper 0.002066115702479339
# proper psychological 0.08333333333333333
# psychological thrillerdrama 0.045454545454545456
# thrillerdrama single 0.5
# single best 0.1
# best character 0.014705882352941176
# character development 0.03968253968253968
# development ever 0.08333333333333333
# ever seenmovie 0.03125
# seenmovie felt 0.5
# felt alone 0.022727272727272728
# alone isolated 0.08333333333333333
# isolated truly 0.5
# truly relate 0.0625
# relate understand 0.125
# understand motive 0.041666666666666664
# motive feel 0.5
# feel sorry 0.029411764705882353
# sorry character 0.16666666666666666
# character lot 0.007936507936507936
# lot people 0.05263157894736842
# people see 0.008620689655172414
# see movie 0.045454545454545456
# movie think 0.002066115702479339
# think encourages 0.017241379310344827
# encourages violence 0.5
# violence truly 0.05
# truly movie 0.0625
# movie encourage 0.002066115702479339
# encourage every 0.5
# every one 0.03571428571428571
# one us 0.009615384615384616
# us become 0.05
# become better 0.041666666666666664
# better person 0.02564102564102564
# person treat 0.02564102564102564
# treat everyone 0.25
# everyone respect 0.045454545454545456
# respect make 0.25
# make feel 0.06666666666666667
# feel like 0.07352941176470588
# like belong 0.008064516129032258
# belong world 0.5
# world instead 0.03333333333333333
# instead making 0.1
# making feel 0.0625
# feel isolatedtruly 0.014705882352941176
# isolatedtruly masterpiece 0.5
# masterpiece best 0.021739130434782608
# best hollywood 0.014705882352941176
# hollywood film 0.07142857142857142
# film 2019 0.006756756756756757
# 2019 one 0.25
# one best 0.07692307692307693
# best films 0.029411764705882353
# films decade 0.027777777777777776
# decade truly 0.25
# truly best 0.0625
# best film 0.014705882352941176
# film bring 0.006756756756756757
# bring comic 0.125
# comic book 0.391304347826087
# book chillingly 0.027777777777777776
# chillingly realistically 0.5
# realistically real 0.5
# real ife 0.022727272727272728
# ife remarkable 0.5
# remarkable direction 0.5
# direction cinematography 0.07142857142857142
# cinematography music 0.05555555555555555
# music acting 0.1
# acting people 0.015151515151515152
# people surprised 0.008620689655172414
# surprised find 0.125
# find disturbing 0.07142857142857142
# disturbing violent 0.08333333333333333
# violent necessity 0.0625
# necessity message 0.5
# message society 0.07142857142857142
# society reflects 0.021739130434782608
# reflects underappreciatedunrecognizedbullied 0.25
# underappreciatedunrecognizedbullied people 0.5
# people proving 0.008620689655172414
# proving something 0.5
# something way 0.03571428571428571
# way shows 0.014285714285714285
# shows class 0.07142857142857142
# class difference 0.1
# difference corruption 0.16666666666666666
# corruption rich 0.5
# rich talented 0.07142857142857142
# talented rule 0.25
# rule others 0.5
# others around 0.125
# around exaggerated 0.0625
# exaggerated thats 0.5
# thats makes 0.02631578947368421
# makes different 0.05
# different believable 0.03333333333333333
# believable could 0.1
# could multiple 0.020833333333333332
# multiple jokers 0.08333333333333333
# jokers living 0.041666666666666664
# living society 0.25
# society could 0.021739130434782608
# could shake 0.020833333333333332
# shake around 0.5
# around much 0.0625
# much bitter 0.015625
# bitter way 0.5
# way film 0.014285714285714285
# film shows 0.006756756756756757
# shows making 0.07142857142857142
# making people 0.03125
# people uncomforting 0.008620689655172414
# uncomforting people 0.5
# people consider 0.008620689655172414
# consider wake 0.125
# wake call 0.3333333333333333
# call message 0.0625
# message first 0.07142857142857142
# first film 0.03571428571428571
# film perfect 0.006756756756756757
# perfect filmtime 0.05
# filmtime movies 0.5
# movies anticipated 0.013513513513513514
# anticipated like 0.5
# like end 0.008064516129032258
# end falling 0.029411764705882353
# falling short 0.25
# short way 0.07142857142857142
# way short 0.014285714285714285
# short joker 0.07142857142857142
# joker first 0.0064516129032258064
# first time 0.17857142857142858
# time happy 0.014285714285714285
# happy hype 0.5
# hype please 0.038461538461538464
# please ignore 0.125
# ignore complaints 0.16666666666666666
# complaints pernicious 0.5
# pernicious violence 0.5
# violence embarrassing 0.05
# embarrassing say 0.5
# say least 0.037037037037037035
# least havent 0.0625
# havent seen 0.25
# seen comic 0.019230769230769232
# comic movie 0.043478260869565216
# movie real 0.002066115702479339
# real ever 0.022727272727272728
# ever deserved 0.03125
# deserved better 0.16666666666666666
# better class 0.02564102564102564
# class criminal 0.1
# criminal phillips 0.16666666666666666
# phillips phoenix 0.08333333333333333
# phoenix delivered 0.009615384615384616
# delivered dark 0.5
# dark joker 0.013513513513513514
# joker dark 0.0032258064516129032
# dark fall 0.013513513513513514
# fall love 0.25
# love villain 0.07142857142857142
# villain bad 0.05555555555555555
# bad guys 0.020833333333333332
# guys always 0.5
# always romantic 0.125
# romantic anywayjoaquin 0.5
# anywayjoaquin phoenix 0.5
# phoenix gives 0.028846153846153848
# gives tour 0.05
# tour de 0.5
# de force 0.0625
# force performance 0.25
# performance fearless 0.015625
# fearless stunning 0.5
# stunning emotional 0.25
# emotional depth 0.2
# depth physicality 0.16666666666666666
# physicality impossible 0.5
# impossible talk 0.16666666666666666
# talk without 0.1
# without referencing 0.038461538461538464
# referencing heath 0.5
# heath ledgers 0.14705882352941177
# ledgers oscarwinning 0.0625
# oscarwinning performance 0.5
# performance dark 0.015625
# dark knight 0.1891891891891892
# knight widely 0.03571428571428571
# widely considered 0.5
# considered definitive 0.25
# definitive liveaction 0.5
# liveaction portrayal 0.5
# portrayal joker 0.07142857142857142
# joker lets 0.0032258064516129032
# lets talk 0.125
# talk fact 0.1
# fact everyone 0.08333333333333333
# everyone going 0.045454545454545456
# going stunned 0.03333333333333333
# stunned phoenix 0.16666666666666666
# phoenix accomplishes 0.009615384615384616
# accomplishes many 0.5
# many thought 0.015151515151515152
# thought impossible 0.041666666666666664
# impossible portrayal 0.16666666666666666
# portrayal matches 0.07142857142857142
# matches potentially 0.5
# potentially exceeds 0.5
# exceeds dark 0.5
# dark knights 0.013513513513513514
# knights clown 0.5
# clown prince 0.125
# prince crimelet 0.125
# crimelet start 0.5
# start saying 0.05555555555555555
# saying joaquin 0.0625
# joaquin phoneix 0.011904761904761904
# phoneix doesnt 0.25
# doesnt get 0.0625
# get oscar 0.038461538461538464
# oscar movie 0.021739130434782608
# movie oscars 0.002066115702479339
# oscars cancelled 0.1
# cancelled phoneix 0.5
# phoneix amazing 0.25
# amazing mightve 0.03571428571428571
# mightve heard 0.5
# heard every 0.16666666666666666
# every review 0.03571428571428571
# review ever 0.05555555555555555
# ever todd 0.03125
# todd phillips 0.34375
# phillips best 0.041666666666666664
# best story 0.014705882352941176
# story lines 0.011627906976744186
# lines takes 0.125
# takes visuals 0.07142857142857142
# visuals breathtaking 0.25
# breathtaking score 0.25
# score omg 0.038461538461538464
# omg score 0.25
# score every 0.038461538461538464
# every time 0.07142857142857142
# time score 0.014285714285714285
# score came 0.038461538461538464
# came felt 0.07142857142857142
# felt uncomfortable 0.022727272727272728
# uncomfortable like 0.125
# like something 0.008064516129032258
# something horrible 0.03571428571428571
# horrible happen 0.25
# happen great 0.07142857142857142
# great inspirations 0.02
# inspirations taxi 0.5
# taxi driver 0.5
# driver king 0.1111111111111111
# king comedy 0.5
# comedy add 0.05555555555555555
# add much 0.16666666666666666
# much movie 0.046875
# movie got 0.004132231404958678
# got honest 0.05
# honest scenes 0.5
# scenes violent 0.029411764705882353
# violent disturbing 0.0625
# disturbing honestly 0.08333333333333333
# honestly expected 0.125
# expected wayyyy 0.16666666666666666
# wayyyy violent 0.5
# violent controversy 0.0625
# controversy going 0.125
# going overall 0.03333333333333333
# overall movie 0.07142857142857142
# movie great 0.006198347107438017
# great come 0.02
# come oscar 0.07142857142857142
# oscar season 0.021739130434782608
# season needs 0.25
# needs nominated 0.16666666666666666
# nominated best 0.25
# best picture 0.014705882352941176
# picture screenplay 0.5
# screenplay cinematography 0.08333333333333333
# cinematography actor 0.027777777777777776
# actor score 0.05
# score directorget 0.038461538461538464
# directorget people 0.5
# people hate 0.008620689655172414
# hate political 0.08333333333333333
# political message 0.25
# message people 0.07142857142857142
# people think 0.017241379310344827
# think need 0.034482758620689655
# need get 0.0625
# get empathy 0.019230769230769232
# empathy arthurs 0.5
# arthurs madness 0.16666666666666666
# madness come 0.5
# come point 0.07142857142857142
# point never 0.045454545454545456
# never enjoy 0.03125
# enjoy masterpiece 0.1
# masterpiece joaquin 0.021739130434782608
# joaquin phoenix 0.2857142857142857
# phoenix todd 0.019230769230769232
# phillips overdid 0.041666666666666664
# overdid movie 0.5
# movie actingmusic 0.002066115702479339
# actingmusic cinematography 0.5
# cinematography amazing 0.027777777777777776
# amazing please 0.03571428571428571
# please enjoy 0.125
# enjoy movie 0.2
# movie without 0.004132231404958678
# without overthinkingseen 0.038461538461538464
# overthinkingseen joker 0.5
# joker yesterday 0.0032258064516129032
# yesterday venice 0.5
# venice early 0.125
# early illfated 0.16666666666666666
# illfated screening 0.5
# screening trouble 0.25
# trouble audio 0.25
# audio lead 0.5
# lead nearhour 0.125
# nearhour delay 0.5
# delay definitely 0.5
# definitely worth 0.041666666666666664
# worth itjoker 0.1
# itjoker deserved 0.5
# deserved presented 0.16666666666666666
# presented venice 0.25
# venice film 0.125
# film festival 0.013513513513513514
# festival event 0.25
# event regards 0.25
# regards cinema 0.25
# cinema form 0.038461538461538464
# form art 0.1
# art film 0.08333333333333333
# film far 0.02027027027027027
# far blockbuster 0.02631578947368421
# blockbuster mere 0.5
# mere entertainer 0.5
# entertainer movie 0.5
# movie films 0.002066115702479339
# films genre 0.027777777777777776
# genre areit 0.08333333333333333
# areit focuses 0.5
# focuses psyche 0.5
# psyche main 0.5
# main character 0.0625
# character slowly 0.015873015873015872
# slowly crumbles 0.08333333333333333
# crumbles pressure 0.5
# pressure society 0.5
# society thus 0.021739130434782608
# thus joaquin 0.5
# phoenix wonderful 0.009615384615384616
# wonderful performance 0.5
# performance earning 0.015625
# earning almost 0.5
# almost surely 0.05
# surely nomination 0.25
# nomination oscars 0.125
# oscars least 0.1
# least take 0.0625
# take joker 0.125
# joker differs 0.0032258064516129032
# differs ledgers 0.5
# ledgers id 0.0625
# id say 0.2
# say equally 0.018518518518518517
# equally good 0.25
# good main 0.00909090909090909
# main difference 0.0625
# difference might 0.16666666666666666
# might ledgers 0.07142857142857142
# ledgers joker 0.1875
# joker rational 0.0032258064516129032
# rational acts 0.5
# acts insane 0.5
# insane phoenixs 0.08333333333333333
# phoenixs insane 0.038461538461538464
# insane rootdespite 0.08333333333333333
# rootdespite movie 0.5
# movie superhero 0.002066115702479339
# superhero villain 0.03571428571428571
# villain joker 0.05555555555555555
# joker much 0.0032258064516129032
# much superior 0.015625
# superior movies 0.5
# movies genre 0.013513513513513514
# genre id 0.08333333333333333
# id exclude 0.1
# exclude dark 0.5
# knight trilogy 0.10714285714285714
# trilogy joker 0.16666666666666666
# joker easily 0.0032258064516129032
# easily good 0.1
# good nolans 0.00909090909090909
# nolans movies 0.25
# movies least 0.013513513513513514
# least close 0.0625
# close smallscaled 0.08333333333333333
# smallscaled film 0.5
# film distinct 0.006756756756756757
# distinct style 0.5
# style cinematography 0.5
# cinematography cannot 0.027777777777777776

# %%
from collections import Counter      #noun phrase
import nltk
from nltk import word_tokenize, pos_tag, pos_tag_sents
nltk.download('averaged_perceptron_tagger')
lower_case = line.lower()
tokens = nltk.word_tokenize(lower_case)
tags = nltk.pos_tag(tokens)
counts = Counter( tag for word,  tag in tags)
highest_noun_count = counts['NN']
df['phrases'] = pos_tag_sents(df['review_content'].apply(word_tokenize).tolist())
y = df['phrases']
list1 = []
list2 = []
for i in y:
  count = Counter( tag for word,  tag in i)
  list1.append(count['NN'])
for i in list1:
  j = i/highest_noun_count
  list2.append(j)
print(list2)
df1 = pd.DataFrame(list1,columns = ['noun_count'])
#df1
df2 = pd. DataFrame(list2,columns = ['prob_noun'])
result = pd.concat([df1,df2], axis=1, sort=False)
#result
finalresult = pd.concat([df,result], axis = 1, sort = False)
del finalresult['noun_phrases']
finalresult
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [0.01242015613910575, 0.0056777856635912, 0.0049680624556423, 0.009226401703335699, 0.0056777856635912, 0.00674237047551455, 0.009226401703335699, 0.0035486160397444995, 0.013839602555003548, 0.008871540099361249, 0.007097232079488999, 0.0056777856635912, 0.0028388928317956, 0.0014194464158978, 0.0007097232079489, 0.01667849538679915, 0.007452093683463449, 0.0234208658623137, 0.020227111426543647, 0.018807665010645847, 0.01242015613910575, 0.021291696238467, 0.00958126330731015, 0.00603264726756565, 0.007806955287437899, 0.007452093683463449, 0.007452093683463449, 0.00603264726756565, 0.029808374733853796, 0.00603264726756565, 0.007452093683463449, 0.014194464158977998, 0.0046132008516678496, 0.0042583392476933995, 0.01242015613910575, 0.013839602555003548, 0.04577714691270404, 0.014904187366926898, 0.0046132008516678496, 0.017743080198722498, 0.0014194464158978, 0.027324343506032647, 0.030872959545777148, 0.014549325762952448, 0.00319375443577005, 0.0049680624556423, 0.014904187366926898, 0.00319375443577005, 0.00603264726756565, 0.0046132008516678496, 0.0042583392476933995, 0.00532292405961675, 0.0042583392476933995, 0.04045422285308729, 0.00248403122782115, 0.0039034776437189495, 0.0039034776437189495, 0.0028388928317956, 0.0056777856635912, 0.00248403122782115, 0.033711852377572744, 0.0010645848119233499, 0.0021291696238466998, 0.07771469127040455, 0.0035486160397444995, 0.0010645848119233499, 0.031227821149751596, 0.007097232079488999, 0.0134847409510291, 0.0046132008516678496, 0.00532292405961675, 0.0319375443577005, 0.00958126330731015, 0.0010645848119233499, 0.0042583392476933995, 0.0049680624556423, 0.008516678495386799, 0.007806955287437899, 0.01242015613910575, 0.0056777856635912, 0.0039034776437189495, 0.00319375443577005, 0.0056777856635912, 0.014904187366926898, 0.0042583392476933995, 0.0021291696238466998, 0.0007097232079489, 0.017743080198722498, 0.00319375443577005, 0.0106458481192335, 0.01242015613910575, 0.01029098651525905, 0.008161816891412349, 0.007097232079488999, 0.00674237047551455, 0.0017743080198722497, 0.0049680624556423, 0.0046132008516678496, 0.0042583392476933995, 0.007806955287437899]
#     Unnamed: 0  ... prob_noun
# 0            0  ...  0.012420
# 1            1  ...  0.005678
# 2            2  ...  0.004968
# 3            3  ...  0.009226
# 4            4  ...  0.005678
# ..         ...  ...       ...
# 95          95  ...  0.001774
# 96          96  ...  0.004968
# 97          97  ...  0.004613
# 98          98  ...  0.004258
# 99          99  ...  0.007807
#
# [100 rows x 6 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (40 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer  #(1) tfidf matrix
text = []
for x in df['review_content']:
  text.append(sent)

vectorizer = TfidfVectorizer(input=text, min_df=0.1, stop_words='english')
tfidfmatrix = vectorizer.fit_transform(text)
attributes = vectorizer.get_feature_names()
index=[n for n in range(1, len(text)+1)]
tfidf=pd.DataFrame(tfidfmatrix.T.todense(), index=attributes, columns=index)
tfidf
# Out:
#                    1        2        3    ...      98       99       100
# 40             0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# acting         0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# better         0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# borrowed       0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# borrowing      0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# caliber        0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# case           0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# characters     0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# dialogue       0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# driver         0.40452  0.40452  0.40452  ...  0.40452  0.40452  0.40452
# earlier        0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# elements       0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# end            0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# execution      0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# film           0.26968  0.26968  0.26968  ...  0.26968  0.26968  0.26968
# homage         0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# isnt           0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# lifted         0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# lines          0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# little         0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# material       0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# movie          0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# network        0.26968  0.26968  0.26968  ...  0.26968  0.26968  0.26968
# notably        0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# originalwatch  0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# placed         0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# polished       0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# remake         0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# scenes         0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# story          0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# taxi           0.40452  0.40452  0.40452  ...  0.40452  0.40452  0.40452
# wholesale      0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
# years          0.13484  0.13484  0.13484  ...  0.13484  0.13484  0.13484
#
# [33 rows x 100 columns]

# %%
import nltk  #cleaning a single sentence
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
query = "While it succeeds in aping the superficial aspects of [Martin] Scorsese's style, Joker lacks the intelligence or gravitas of Scorsese's best work"
lemmatizer = WordNetLemmatizer()
regex = re.compile('[^a-zA-Z\s]')

def cleaningdata(text):
  text =  re.sub(regex, '', text) # Removes Special characters 
  words = " ".join([word for word in text.split() if word not in stopwords.words('english')]) # removes stopwords from text
  lemmatize =   " ".join([lemmatizer.lemmatize(i) for i in words.lower().split()]) # makes word in to meaning
  return lemmatize
cleaned_query = cleaningdata(query)
print('Cleaned Query: ' + cleaned_query)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Cleaned Query: while succeeds aping superficial aspect martin scorsese style joker lack intelligence gravitas scorsese best work

# %%
#cosine similarity
import pandas
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
text = []
for x in df['review_content']:
  text.append(x)

text.append(cleaned_query)
vectorizer = TfidfVectorizer(input=text, min_df=0.1, stop_words='english')
matrix = vectorizer.fit_transform(text)

cs_dict = {}
for i in range(0, matrix.shape[0]):
  sim=cosine_similarity(matrix[80], matrix[i])
  cs_dict[str(i)] = sim[0][0]
  i+=1

sorted_keys = (sorted(cs_dict, key=cs_dict.get,reverse=True))
sorted_cosine_dict = {}
for key in sorted_keys:
  sorted_cosine_dict[key] = cs_dict[key];

review_content = []
cos = []
for y in sorted_cosine_dict:
  review_content.append(corpus[int(y)])
  cos.append(sorted_cosine_dict[y])
df1 = pd.DataFrame(review_content, columns = ['review'])

df1['Rank'] = [i for i in range(1, len(sorted_keys)+1)]
df1['Cossim'] = cos
df1.head(5)
# Out:
#                                               review  Rank    Cossim
# 0  looking forward film given hype brilliant acti...     1  1.000000
# 1  heard everyone saying film year reviews floodi...     2  0.501203
# 2  truly masterpiece best hollywood film 2019 one...     3  0.396959
# 3  dark depressing unsettling film haunting score...     4  0.386556
# 4  perfect portrait decline insanity joaquin phoe...     5  0.346806

# %% [markdown]
# # **Question 3: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %% [markdown]
# #github link of csv file
# https://github.com/anandp8181/INFO5731_Spring2020/blob/master/review_data(5731).csv
